# %% [markdown]
# <a href="https://colab.research.google.com/github/akankshapatel1/My-notebooks/blob/main/Numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is the first notebook

# %%
# Floor Division
7%4
# Out:
# 3

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = a + a

# %%
a
# Out:
# 10

# %%
m = 1
x = 3
c = 5

# %%
y=m*x+c

# %%
y
# Out:
# 8

# %%
print(y)
# Out:
# 8
